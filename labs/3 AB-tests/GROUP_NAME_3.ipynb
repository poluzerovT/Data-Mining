# %% [markdown]
# # ОИАД. Лабораторная работа 3
#
# * Сбор и обработка данных
# * Разведочный анализ
# * Формулирование и проверка гипотез однородности выборок
#
#
# ## Просьба к формату сдачи
# * отправляйте на почту tpoluzerov@gmail.com
# * тему письма и имя файла заполняйте по шаблону: ГРУППА_ФАМИЛИЯ_НОМЕРЛАБЫ (пример: 10_Иванов_2)
# * дедлайн - **24.10 22:00**
# * каждая неделя просрочки сдачи - снижение оценки на 2 балла
# * вопросы и предложения можно отправлять на почту
#
# Успехов!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#   is_stud   group sex          work_status fav_year  visit_freq  usd_pred  \
# 0     Нет      13   М  Да, неполная ставка      1-2          10      3.31
# 1     Нет  другая   Ж    Да, полная ставка      3-4           8      3.30
# 2     Нет  другая   М  Да, неполная ставка      1-2           1      5.00
# 3      Да      13   М    Да, полная ставка      3-4           6      3.20
# 4      Да      12   Ж                  Нет      3-4          10      2.00
#
#    random_value
# 0          0.56
# 1          0.50
# 2          0.00
# 3          0.04
# 4          0.98

# %% [markdown]
# В таблице приведены названия стобцов и соответсвующие им вопросы
#
# | Название столбца | Вопрос |
# |--|--|
# | is_stud  | Вы студент?	|
# | group | Из какой вы группы? |
# | sex | Ваш пол |
# | work_status | Вы работаете?
# | fav_year | Какой год обучения вам понравился больше всего? |
# | visit_freq | Оцените, как часто вы посещаете пары? |
# | usd_pred | Ваш прогноз на курс доллара на 01.01.2025 |
# | random_value | Сгенерируйте число от 0 до 1 |

# %% [markdown]
# # Задание 1. Знакомство с данным
# * Познакомиться с данными
# * Визуализировать данные
# * Рассчитать некоторые базовые статистики
# * Кратенько **описать текстом** имеющиеся данные
#
# Цель данного задания - дать предстваление о структуре имеющихся данных.
#
# Например, описать данные, отвечая на такого рода вопросы: сколько всего мальичков/девочек, какая доля работающих в разных группах, и другие...

# %% [markdown]
# # Задание 2. Гипотезы для бинарной метрики
#
# ### Пример формулировки гипотезы:
# Предположим, что каждый студент с некоторой вероятностью $p$ приходит на занятие.
#
#
# Студентов можно разделить на 2 группы по признаку наличия работы.
# $X_1$ - работающие студенты
# $X_2$ - не работаюище
#
#
# Хотим проверить, одинаковая ли частота посещения пар среди групп.
# $H_0: {p_1 = p_2}$
#
#
# Гипотеза: **Фактор "студент работает/не работает" не влияет на "посещаемость"**
#
# ---
#
# Необходимо:
# * Выдвинуть 2 гипотезы относительно влияния фактора на **бинарную** метрику
# * С помощью **Биномиального теста** проверить гипотезы
# * Дать текстовую интерпретацию полученных результатов
#
# * **!!! Логику работы Биномиального теста - реализуйте сами**. Для определения критических значений биномиального распределения можно использовать готовые реализации
#
# Для справки:
#
# * https://habr.com/ru/articles/783816/
# * https://en.wikipedia.org/wiki/Binomial_test

# %% [markdown]
# # Задание 3. Гипотезы для непрерывной метрики
#
# Необходимо:
# * Выдвинуть 2 гипотезы относительно влияния фактора на **непрерывную** метрику
# * С помощью **t-критерия Стьюдента** проверить гипотезы. Можно использовать готовые реализации теста
# * Дать текстовую интерпретацию полученных результатов
